# %% [markdown]
# # **0. 해커톤 진행 주의사항**
#
# **1)  개발 관련 주의사항**
# *   [1. 초기 환경 설정]은 절대 수정하지 말 것
# *   모든 구현은 [2. 데이터 전처리] 및 [3.모델 생성]에서만 진행
# *   [4. 모델 저장]에서 team_name 변수 변경 (예.`team_name = 'team01'`)
#  *    트레이닝 중간에 checkpoint를 활용하여 모델을 저장한 경우에도 파일 이름 양식 통일 필수
# *   Colab 사용중 실수로 데이터 손실이 발생할 수도 있으니 중간 결과값을 github에 업로드
#  *    "런타임->모든 런타임 재설정"은 절대 누르지 말 것 (저장한 모델 데이터가 모두 삭제됨)
# *   효율적인 구현 및 테스팅을 위해 GPU 가속 기능 활성화
#  *    "런타임 -> 런타임 유형변경 -> 하드웨어 가속기 -> GPU 설정"
# *   주석을 최대한 자세히 작성
# *   Keras API 관련하여 [Keras Documentation](https://keras.io/) 참조
#
# **2) 제출 관련 주의사항**
# *  제출물
#  *  소스코드 (hackathon_teamXX.ipynb)
#  *  컴파일된 모델 파일 (model_entire_teamXX.h5)
#  *  모델 발표 자료
# * 제출 기한: **오후 6시 (단, 발표자료는 12시)**
# * 제출 방법: [GitHub README](https://github.com/cauosshackathonta/2021_cau_oss_hackathon/) 참조
#
#
# **3) 평가 관련 주의사항**
# *  모델 성능 = 두개의 테스트 데이터 셋 분류 정확도에 대한 weighted sum
#  *  model.evaluate(x_test1, y_test1) + model.evaluate(x_test2, y_test2) * 2
# *  제출된 모델들의 테스트 데이터 셋 분류 정확도를 기준으로 수상작 결정
# *  수상 후보들에 대해서는 소스코드를 기반으로 모델 재검증
#
# **4) 수상 실격 사유**
# *  유사한 소스코드 or 알고리즘이 적발될 경우
# *  소스코드와 제출된 모델이 상이한 경우
# *  개발 관련 주의사항을 지키지 않은 경우
#  *  예: [초기 환경 설정]을 수정한 경우
# *  데이터 셋을 변조한 경우
#  *  예: 테스트 데이터 셋을 트레이닝 데이터 셋에 포함하여 모델 생성
#  *  단, tensorflow.data 및 dataset API를 사용하기 위해 변경하는 것은 허용. 이 경우, model evaluation 파트도 해당 API를 쓰도록 변경
# *  주석이 소스코드와 맞지 않거나 미비할 경우

# %% [markdown]
# # **1. 초기 환경 설정**

# %%
# tensorflow와 tf.keras 및 관련 라이브러리 임포트
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow import keras
from keras.utils import np_utils

# 데이터셋 로드 (Training dataset: CIFAR10, test dataset: CIFAR10 & CIFAR10의 변형)
(x_train, y_train), (x_test1, y_test1) = keras.datasets.cifar10.load_data()

test_ds2 = tfds.load('cifar10_1/v6', split='test', shuffle_files=False, batch_size=-1)
test_ds2 = tfds.as_numpy(test_ds2)
x_test2, y_test2 = test_ds2['image'], test_ds2['label']

#분류를 위해 클래스 벡터를 바이너리 매트릭스로 변환
y_train = np_utils.to_categorical(y_train)
y_test1 = np_utils.to_categorical(y_test1)
y_test2 = np_utils.to_categorical(y_test2)

# 총 클래스 개수
num_classes = y_train.shape[1]
input_shape = x_train.shape[1:]
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# 170508288/170498071 [==============================] - 4s 0us/step
# Downloading and preparing dataset cifar10_1/v6/1.1.0 (download: 5.87 MiB, generated: 4.40 MiB, total: 10.27 MiB) to /root/tensorflow_datasets/cifar10_1/v6/1.1.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/cifar10_1/v6/1.1.0.incomplete96DCRM/cifar10_1-test.tfrecord
#   0%|          | 0/2000 [00:00<?, ? examples/s]
# Dataset cifar10_1 downloaded and prepared to /root/tensorflow_datasets/cifar10_1/v6/1.1.0. Subsequent calls will reuse this data.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/dataset_builder.py:598: get_single_element (from tensorflow.python.data.experimental.ops.get_single_element) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.get_single_element()`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_datasets/core/dataset_builder.py:598: get_single_element (from tensorflow.python.data.experimental.ops.get_single_element) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.get_single_element()`.

# %% [markdown]
# # **2. 데이터 전처리**

# %%
# 데이터 전처리 (예: normalization)
# 원본 데이터와 전처리 후 데이터를 구분하기 위해, 변수명 x_train_after, x_test1_after, x_test2_after를 변경하지 말 것
x_train_after = x_train / 255.0
x_test1_after = x_test1 / 255.0
x_test2_after = x_test2 / 255.0

# %%
import numpy as np
print('x_train mean : ', np.mean(x_train))
print('x_test1 mean : ', np.mean(x_test1))
print('x_test2 mean : ', np.mean(x_test2))

print('x_train std : ', np.std(x_train))
print('x_test1 std : ', np.std(x_test1))
print('x_test2 std : ', np.std(x_test2))
# Out:
# x_train mean :  120.70756512369792
# x_test1 mean :  121.52915475260417
# x_test2 mean :  121.93687776692708
# x_train std :  64.1500758911213
# x_test1 std :  64.06097012299574
# x_test2 std :  65.75933956009034

# %%
# x_train의 mean과 std를 구하여 normalization 진행
# x_train, x_test1, x_test2를 x_train의 mean, std를 이용하여 normalization

x_train_after = (x_train-np.mean(x_train))/np.std(x_train)
x_test1_after = (x_test1 - np.mean(x_train))/np.std(x_train)
x_test2_after = (x_test2-np.mean(x_train))/np.std(x_train)

# %%
print("=== x_train_after : Mean, Std ===")
print(np.mean(x_train_after))
print(np.std(x_train_after))

print("\n=== x_test1_after : Mean, Std ===")
print(np.mean(x_test1_after))
print(np.std(x_test1_after))

print("\n=== x_train_after : Mean, Std ===")
print(np.mean(x_test2_after))
print(np.std(x_test2_after))
# Out:
# === x_train_after : Mean, Std ===
# -2.5247951877342226e-17
# 1.0000000000000022
#
# === x_test1_after : Mean, Std ===
# 0.012807305642173993
# 0.9986109795368484
#
# === x_train_after : Mean, Std ===
# 0.01916307387251756
# 1.0250859199558913

# %%
print('x_train_after : ', x_train_after.shape)
print('x_test1_after : ', x_test1_after.shape)
print('x_test2_after : ', x_test2_after.shape)
# Out:
# x_train_after :  (50000, 32, 32, 3)
# x_test1_after :  (10000, 32, 32, 3)
# x_test2_after :  (2000, 32, 32, 3)

# %% [markdown]
# # Data Augmentation

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Code for Cutout Augmentation
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
image_generator = ImageDataGenerator(
    rotation_range=10,
    zoom_range=0.10,
    shear_range=0.5,
    width_shift_range=0.10,
    height_shift_range=0.10,
    horizontal_flip=True,
    vertical_flip=False,
    fill_mode='nearest',
    preprocessing_function = get_random_eraser(v_l=0, v_h=255),
)

# %%
image_generator.fit(x_train_after, augment=True)

train_size = x_train_after.shape[0]
augment_size=100000
# x_train_after에서 random으로 뽑아와서 해당 데이터를 augmentation 진행
idx = np.random.randint(train_size, size=augment_size)
x_augmented = x_train_after[idx].copy()
y_augmented = y_train[idx].copy()
x_augmented = image_generator.flow(x_augmented, np.zeros(augment_size), batch_size=augment_size, shuffle=False).next()[0]

# %%
print('x_augmented shape : ', x_augmented.shape)
print('y_augmented shape : ', y_augmented.shape)
# Out:
# x_augmented shape :  (100000, 32, 32, 3)
# y_augmented shape :  (100000, 10)

# %%
# 기존 데이터와 추가된 이미지 합치기
x_train_after = np.concatenate((x_train_after, x_augmented))
y_train = np.concatenate((y_train, y_augmented))

# %%
print(x_train_after.shape)
print(y_train.shape)
# Out:
# (150000, 32, 32, 3)
# (150000, 10)

# %% [markdown]
# # **3. 모델 생성**

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, LeakyReLU, Activation
from keras.layers import BatchNormalization
# from keras.layers.advanced_activations import LeakyReLU


model = Sequential()

# model.add(Conv2D(32, (3, 3), input_shape = input_shape))
# model.add(Activation('relu'))
model.add(Conv2D(64, kernel_initializer='glorot_uniform', kernel_size=(3,3), strides=(1,1), padding='same', input_shape = input_shape))
model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Dropout(0.2))

# model.add(Conv2D(32,(3,3)))
# model.add(Activation('relu'))
model.add(Conv2D(64, kernel_initializer='glorot_uniform', kernel_size=(3,3), strides=(1,1), padding='same', input_shape = input_shape))
model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Dropout(0.2))

# model.add(Conv2D(64, (2, 2)))
# model.add(Activation('relu'))
model.add(Conv2D(128, kernel_initializer='glorot_uniform', kernel_size=(3,3), strides=(1,1), padding='same', input_shape = input_shape))
model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Dropout(0.2))

# model.add(Conv2D(64, (3, 3)))
model.add(Conv2D(128, kernel_initializer='glorot_uniform', kernel_size=(3,3), strides=(1,1), padding='same', input_shape = input_shape))
model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Dropout(0.2))

# model.add(Conv2D(128, (3, 3)))
model.add(Conv2D(256, kernel_initializer='glorot_uniform', kernel_size=(3,3), strides=(1,1), padding='same', input_shape = input_shape))
model.add(LeakyReLU(alpha=0.01))
model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Dropout(0.2))

# model.add(Conv2D(128, (3, 3)))
model.add(Conv2D(256, kernel_initializer='glorot_uniform', kernel_size=(3,3), strides=(1,1), padding='same', input_shape = input_shape))
model.add(LeakyReLU(alpha=0.01))
# model.add(MaxPooling2D(pool_size = (2,2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dense(512, activation='relu'))
# model.add(Activation('relu'))
model.add(LeakyReLU(alpha=0.01))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(BatchNormalization())
model.add(Activation('softmax'))

model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
# from keras.callbacks import ModelCheckpoint, EarlyStopping

# 체크포인트 생성
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath='/content/checkpoint_entire_best.h5', monitor='val_accuracy', verbose=1, save_weight_only=False, save_best_only=True, mode='auto')

earlystopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',  # 모니터 기준 설정 (val loss) 
                              patience=10,         # 10회 Epoch동안 개선되지 않는다면 종료
                             )
# 모델 트레이닝
# batch_size: 전체 데이터셋 중 몇개씩 학습시킬 것인지
# epoch: 학습에 전체 데이터셋이 총 몇번 이용될 것인지
# shuffle: 학습전에 트레이닝 데이터셋을 랜덤하게 섞을 것인지
# validation_data: 중간 성능 검증에 사용할 data set (x_test1_after, x_test2_after, 혹은 둘을 merge해서 사용)
model.fit(x_train_after, y_train, batch_size = 128, epochs = 100, shuffle=True, callbacks=[cp_callback], validation_data=(x_test2_after, y_test2))
# Out:
# Epoch 1/100
# 1172/1172 [==============================] - 48s 14ms/step - loss: 2.3108 - accuracy: 0.0997 - val_loss: 2.3027 - val_accuracy: 0.1000
#
# Epoch 00001: val_accuracy improved from -inf to 0.10000, saving model to /content/checkpoint_entire_best.h5
# Epoch 2/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 2.2455 - accuracy: 0.1313 - val_loss: 2.0764 - val_accuracy: 0.2010
#
# Epoch 00002: val_accuracy improved from 0.10000 to 0.20100, saving model to /content/checkpoint_entire_best.h5
# Epoch 3/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 1.7153 - accuracy: 0.3445 - val_loss: 1.6246 - val_accuracy: 0.4035
#
# Epoch 00003: val_accuracy improved from 0.20100 to 0.40350, saving model to /content/checkpoint_entire_best.h5
# Epoch 4/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 1.3860 - accuracy: 0.5020 - val_loss: 1.4934 - val_accuracy: 0.4640
#
# Epoch 00004: val_accuracy improved from 0.40350 to 0.46400, saving model to /content/checkpoint_entire_best.h5
# Epoch 5/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 1.2243 - accuracy: 0.5681 - val_loss: 1.3215 - val_accuracy: 0.5400
#
# Epoch 00005: val_accuracy improved from 0.46400 to 0.54000, saving model to /content/checkpoint_entire_best.h5
# Epoch 6/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 1.1190 - accuracy: 0.6080 - val_loss: 1.2263 - val_accuracy: 0.5715
#
# Epoch 00006: val_accuracy improved from 0.54000 to 0.57150, saving model to /content/checkpoint_entire_best.h5
# Epoch 7/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 1.0464 - accuracy: 0.6368 - val_loss: 1.2236 - val_accuracy: 0.5760
#
# Epoch 00007: val_accuracy improved from 0.57150 to 0.57600, saving model to /content/checkpoint_entire_best.h5
# Epoch 8/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.9925 - accuracy: 0.6544 - val_loss: 1.1264 - val_accuracy: 0.6120
#
# Epoch 00008: val_accuracy improved from 0.57600 to 0.61200, saving model to /content/checkpoint_entire_best.h5
# Epoch 9/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.9447 - accuracy: 0.6722 - val_loss: 1.1137 - val_accuracy: 0.6070
#
# Epoch 00009: val_accuracy did not improve from 0.61200
# Epoch 10/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.9061 - accuracy: 0.6868 - val_loss: 1.1244 - val_accuracy: 0.6150
#
# Epoch 00010: val_accuracy improved from 0.61200 to 0.61500, saving model to /content/checkpoint_entire_best.h5
# Epoch 11/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.8743 - accuracy: 0.6991 - val_loss: 1.0632 - val_accuracy: 0.6440
#
# Epoch 00011: val_accuracy improved from 0.61500 to 0.64400, saving model to /content/checkpoint_entire_best.h5
# Epoch 12/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.8457 - accuracy: 0.7071 - val_loss: 1.0420 - val_accuracy: 0.6380
#
# Epoch 00012: val_accuracy did not improve from 0.64400
# Epoch 13/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.8227 - accuracy: 0.7151 - val_loss: 1.0149 - val_accuracy: 0.6470
#
# Epoch 00013: val_accuracy improved from 0.64400 to 0.64700, saving model to /content/checkpoint_entire_best.h5
# Epoch 14/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.8041 - accuracy: 0.7203 - val_loss: 0.9801 - val_accuracy: 0.6630
#
# Epoch 00014: val_accuracy improved from 0.64700 to 0.66300, saving model to /content/checkpoint_entire_best.h5
# Epoch 15/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.7838 - accuracy: 0.7291 - val_loss: 0.9953 - val_accuracy: 0.6665
#
# Epoch 00015: val_accuracy improved from 0.66300 to 0.66650, saving model to /content/checkpoint_entire_best.h5
# Epoch 16/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.7647 - accuracy: 0.7360 - val_loss: 0.9961 - val_accuracy: 0.6625
#
# Epoch 00016: val_accuracy did not improve from 0.66650
# Epoch 17/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.7530 - accuracy: 0.7394 - val_loss: 0.9697 - val_accuracy: 0.6660
#
# Epoch 00017: val_accuracy did not improve from 0.66650
# Epoch 18/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.7347 - accuracy: 0.7452 - val_loss: 0.9719 - val_accuracy: 0.6710
#
# Epoch 00018: val_accuracy improved from 0.66650 to 0.67100, saving model to /content/checkpoint_entire_best.h5
# Epoch 19/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.7245 - accuracy: 0.7497 - val_loss: 0.9612 - val_accuracy: 0.6835
#
# Epoch 00019: val_accuracy improved from 0.67100 to 0.68350, saving model to /content/checkpoint_entire_best.h5
# Epoch 20/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.7094 - accuracy: 0.7546 - val_loss: 0.9326 - val_accuracy: 0.6845
#
# Epoch 00020: val_accuracy improved from 0.68350 to 0.68450, saving model to /content/checkpoint_entire_best.h5
# Epoch 21/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.7018 - accuracy: 0.7572 - val_loss: 0.9263 - val_accuracy: 0.6850
#
# Epoch 00021: val_accuracy improved from 0.68450 to 0.68500, saving model to /content/checkpoint_entire_best.h5
# Epoch 22/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.6869 - accuracy: 0.7626 - val_loss: 0.9626 - val_accuracy: 0.6765
#
# Epoch 00022: val_accuracy did not improve from 0.68500
# Epoch 23/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.6789 - accuracy: 0.7661 - val_loss: 0.9369 - val_accuracy: 0.6810
#
# Epoch 00023: val_accuracy did not improve from 0.68500
# Epoch 24/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.6712 - accuracy: 0.7681 - val_loss: 0.8966 - val_accuracy: 0.6970
#
# Epoch 00024: val_accuracy improved from 0.68500 to 0.69700, saving model to /content/checkpoint_entire_best.h5
# Epoch 25/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.6631 - accuracy: 0.7713 - val_loss: 0.9550 - val_accuracy: 0.6785
#
# Epoch 00025: val_accuracy did not improve from 0.69700
# Epoch 26/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.6548 - accuracy: 0.7735 - val_loss: 0.9378 - val_accuracy: 0.6765
#
# Epoch 00026: val_accuracy did not improve from 0.69700
# Epoch 27/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.6505 - accuracy: 0.7746 - val_loss: 0.9199 - val_accuracy: 0.6935
#
# Epoch 00027: val_accuracy did not improve from 0.69700
# Epoch 28/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.6427 - accuracy: 0.7772 - val_loss: 0.8956 - val_accuracy: 0.7000
#
# Epoch 00028: val_accuracy improved from 0.69700 to 0.70000, saving model to /content/checkpoint_entire_best.h5
# Epoch 29/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.6320 - accuracy: 0.7814 - val_loss: 0.9267 - val_accuracy: 0.6940
#
# Epoch 00029: val_accuracy did not improve from 0.70000
# Epoch 30/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.6274 - accuracy: 0.7823 - val_loss: 0.9328 - val_accuracy: 0.6945
#
# Epoch 00030: val_accuracy did not improve from 0.70000
# Epoch 31/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.6207 - accuracy: 0.7851 - val_loss: 0.8961 - val_accuracy: 0.7045
#
# Epoch 00031: val_accuracy improved from 0.70000 to 0.70450, saving model to /content/checkpoint_entire_best.h5
# Epoch 32/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.6145 - accuracy: 0.7866 - val_loss: 0.9432 - val_accuracy: 0.6950
#
# Epoch 00032: val_accuracy did not improve from 0.70450
# Epoch 33/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.6068 - accuracy: 0.7908 - val_loss: 0.8839 - val_accuracy: 0.7050
#
# Epoch 00033: val_accuracy improved from 0.70450 to 0.70500, saving model to /content/checkpoint_entire_best.h5
# Epoch 34/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.6052 - accuracy: 0.7911 - val_loss: 0.9435 - val_accuracy: 0.6910
#
# Epoch 00034: val_accuracy did not improve from 0.70500
# Epoch 35/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.6006 - accuracy: 0.7922 - val_loss: 0.9210 - val_accuracy: 0.6955
#
# Epoch 00035: val_accuracy did not improve from 0.70500
# Epoch 36/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5912 - accuracy: 0.7959 - val_loss: 0.9131 - val_accuracy: 0.6950
#
# Epoch 00036: val_accuracy did not improve from 0.70500
# Epoch 37/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5875 - accuracy: 0.7963 - val_loss: 0.9217 - val_accuracy: 0.6990
#
# Epoch 00037: val_accuracy did not improve from 0.70500
# Epoch 38/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5849 - accuracy: 0.7970 - val_loss: 0.8790 - val_accuracy: 0.7125
#
# Epoch 00038: val_accuracy improved from 0.70500 to 0.71250, saving model to /content/checkpoint_entire_best.h5
# Epoch 39/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5792 - accuracy: 0.7996 - val_loss: 0.9228 - val_accuracy: 0.6970
#
# Epoch 00039: val_accuracy did not improve from 0.71250
# Epoch 40/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5747 - accuracy: 0.8010 - val_loss: 0.8937 - val_accuracy: 0.7085
#
# Epoch 00040: val_accuracy did not improve from 0.71250
# Epoch 41/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5697 - accuracy: 0.8030 - val_loss: 0.9829 - val_accuracy: 0.6965
#
# Epoch 00041: val_accuracy did not improve from 0.71250
# Epoch 42/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5657 - accuracy: 0.8043 - val_loss: 0.8961 - val_accuracy: 0.7180
#
# Epoch 00042: val_accuracy improved from 0.71250 to 0.71800, saving model to /content/checkpoint_entire_best.h5
# Epoch 43/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5637 - accuracy: 0.8043 - val_loss: 0.9180 - val_accuracy: 0.7025
#
# Epoch 00043: val_accuracy did not improve from 0.71800
# Epoch 44/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5554 - accuracy: 0.8080 - val_loss: 0.9050 - val_accuracy: 0.7055
#
# Epoch 00044: val_accuracy did not improve from 0.71800
# Epoch 45/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5591 - accuracy: 0.8057 - val_loss: 0.8676 - val_accuracy: 0.7110
#
# Epoch 00045: val_accuracy did not improve from 0.71800
# Epoch 46/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5529 - accuracy: 0.8085 - val_loss: 0.8851 - val_accuracy: 0.7030
#
# Epoch 00046: val_accuracy did not improve from 0.71800
# Epoch 47/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5458 - accuracy: 0.8096 - val_loss: 0.9020 - val_accuracy: 0.7020
#
# Epoch 00047: val_accuracy did not improve from 0.71800
# Epoch 48/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5436 - accuracy: 0.8121 - val_loss: 0.9175 - val_accuracy: 0.6985
#
# Epoch 00048: val_accuracy did not improve from 0.71800
# Epoch 49/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5405 - accuracy: 0.8126 - val_loss: 0.8961 - val_accuracy: 0.6995
#
# Epoch 00049: val_accuracy did not improve from 0.71800
# Epoch 50/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5371 - accuracy: 0.8140 - val_loss: 0.8895 - val_accuracy: 0.7045
#
# Epoch 00050: val_accuracy did not improve from 0.71800
# Epoch 51/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5347 - accuracy: 0.8152 - val_loss: 0.8728 - val_accuracy: 0.7170
#
# Epoch 00051: val_accuracy did not improve from 0.71800
# Epoch 52/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.5311 - accuracy: 0.8167 - val_loss: 0.8885 - val_accuracy: 0.7100
#
# Epoch 00052: val_accuracy did not improve from 0.71800
# Epoch 53/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5302 - accuracy: 0.8165 - val_loss: 0.8865 - val_accuracy: 0.7200
#
# Epoch 00053: val_accuracy improved from 0.71800 to 0.72000, saving model to /content/checkpoint_entire_best.h5
# Epoch 54/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5247 - accuracy: 0.8176 - val_loss: 0.8917 - val_accuracy: 0.7065
#
# Epoch 00054: val_accuracy did not improve from 0.72000
# Epoch 55/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.5237 - accuracy: 0.8170 - val_loss: 0.8800 - val_accuracy: 0.7115
#
# Epoch 00055: val_accuracy did not improve from 0.72000
# Epoch 56/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5184 - accuracy: 0.8202 - val_loss: 0.8824 - val_accuracy: 0.7130
#
# Epoch 00056: val_accuracy did not improve from 0.72000
# Epoch 57/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5195 - accuracy: 0.8196 - val_loss: 0.8811 - val_accuracy: 0.7120
#
# Epoch 00057: val_accuracy did not improve from 0.72000
# Epoch 58/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5154 - accuracy: 0.8203 - val_loss: 0.8764 - val_accuracy: 0.7195
#
# Epoch 00058: val_accuracy did not improve from 0.72000
# Epoch 59/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5112 - accuracy: 0.8223 - val_loss: 0.8771 - val_accuracy: 0.7160
#
# Epoch 00059: val_accuracy did not improve from 0.72000
# Epoch 60/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5082 - accuracy: 0.8245 - val_loss: 0.8898 - val_accuracy: 0.7100
#
# Epoch 00060: val_accuracy did not improve from 0.72000
# Epoch 61/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.5041 - accuracy: 0.8252 - val_loss: 0.8670 - val_accuracy: 0.7205
#
# Epoch 00061: val_accuracy improved from 0.72000 to 0.72050, saving model to /content/checkpoint_entire_best.h5
# Epoch 62/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.5051 - accuracy: 0.8243 - val_loss: 0.8919 - val_accuracy: 0.7170
#
# Epoch 00062: val_accuracy did not improve from 0.72050
# Epoch 63/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.5006 - accuracy: 0.8255 - val_loss: 0.8512 - val_accuracy: 0.7180
#
# Epoch 00063: val_accuracy did not improve from 0.72050
# Epoch 64/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4989 - accuracy: 0.8273 - val_loss: 0.8935 - val_accuracy: 0.7090
#
# Epoch 00064: val_accuracy did not improve from 0.72050
# Epoch 65/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4949 - accuracy: 0.8279 - val_loss: 0.8983 - val_accuracy: 0.7040
#
# Epoch 00065: val_accuracy did not improve from 0.72050
# Epoch 66/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4932 - accuracy: 0.8295 - val_loss: 0.9074 - val_accuracy: 0.7135
#
# Epoch 00066: val_accuracy did not improve from 0.72050
# Epoch 67/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4897 - accuracy: 0.8296 - val_loss: 0.8873 - val_accuracy: 0.7190
#
# Epoch 00067: val_accuracy did not improve from 0.72050
# Epoch 68/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4918 - accuracy: 0.8295 - val_loss: 0.9059 - val_accuracy: 0.7185
#
# Epoch 00068: val_accuracy did not improve from 0.72050
# Epoch 69/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.4884 - accuracy: 0.8311 - val_loss: 0.8754 - val_accuracy: 0.7175
#
# Epoch 00069: val_accuracy did not improve from 0.72050
# Epoch 70/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4830 - accuracy: 0.8316 - val_loss: 0.8970 - val_accuracy: 0.7065
#
# Epoch 00070: val_accuracy did not improve from 0.72050
# Epoch 71/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.4856 - accuracy: 0.8318 - val_loss: 0.8992 - val_accuracy: 0.7130
#
# Epoch 00071: val_accuracy did not improve from 0.72050
# Epoch 72/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4816 - accuracy: 0.8332 - val_loss: 0.9248 - val_accuracy: 0.7125
#
# Epoch 00072: val_accuracy did not improve from 0.72050
# Epoch 73/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4807 - accuracy: 0.8327 - val_loss: 0.8897 - val_accuracy: 0.7105
#
# Epoch 00073: val_accuracy did not improve from 0.72050
# Epoch 74/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4769 - accuracy: 0.8338 - val_loss: 0.8849 - val_accuracy: 0.7155
#
# Epoch 00074: val_accuracy did not improve from 0.72050
# Epoch 75/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4739 - accuracy: 0.8356 - val_loss: 0.8945 - val_accuracy: 0.7130
#
# Epoch 00075: val_accuracy did not improve from 0.72050
# Epoch 76/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4731 - accuracy: 0.8354 - val_loss: 0.8868 - val_accuracy: 0.7180
#
# Epoch 00076: val_accuracy did not improve from 0.72050
# Epoch 77/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.4738 - accuracy: 0.8343 - val_loss: 0.8942 - val_accuracy: 0.7185
#
# Epoch 00077: val_accuracy did not improve from 0.72050
# Epoch 78/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4702 - accuracy: 0.8354 - val_loss: 0.8789 - val_accuracy: 0.7155
#
# Epoch 00078: val_accuracy did not improve from 0.72050
# Epoch 79/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4671 - accuracy: 0.8377 - val_loss: 0.8873 - val_accuracy: 0.7180
#
# Epoch 00079: val_accuracy did not improve from 0.72050
# Epoch 80/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4668 - accuracy: 0.8375 - val_loss: 0.8996 - val_accuracy: 0.7135
#
# Epoch 00080: val_accuracy did not improve from 0.72050
# Epoch 81/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4650 - accuracy: 0.8385 - val_loss: 0.8856 - val_accuracy: 0.7180
#
# Epoch 00081: val_accuracy did not improve from 0.72050
# Epoch 82/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4650 - accuracy: 0.8385 - val_loss: 0.8732 - val_accuracy: 0.7140
#
# Epoch 00082: val_accuracy did not improve from 0.72050
# Epoch 83/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.4626 - accuracy: 0.8395 - val_loss: 0.9012 - val_accuracy: 0.7065
#
# Epoch 00083: val_accuracy did not improve from 0.72050
# Epoch 84/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.4575 - accuracy: 0.8411 - val_loss: 0.8879 - val_accuracy: 0.7195
#
# Epoch 00084: val_accuracy did not improve from 0.72050
# Epoch 85/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4598 - accuracy: 0.8384 - val_loss: 0.8923 - val_accuracy: 0.7180
#
# Epoch 00085: val_accuracy did not improve from 0.72050
# Epoch 86/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4552 - accuracy: 0.8410 - val_loss: 0.9086 - val_accuracy: 0.7065
#
# Epoch 00086: val_accuracy did not improve from 0.72050
# Epoch 87/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4577 - accuracy: 0.8413 - val_loss: 0.8831 - val_accuracy: 0.7205
#
# Epoch 00087: val_accuracy did not improve from 0.72050
# Epoch 88/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4532 - accuracy: 0.8419 - val_loss: 0.8889 - val_accuracy: 0.7170
#
# Epoch 00088: val_accuracy did not improve from 0.72050
# Epoch 89/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4530 - accuracy: 0.8414 - val_loss: 0.9034 - val_accuracy: 0.7135
#
# Epoch 00089: val_accuracy did not improve from 0.72050
# Epoch 90/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4477 - accuracy: 0.8440 - val_loss: 0.8870 - val_accuracy: 0.7190
#
# Epoch 00090: val_accuracy did not improve from 0.72050
# Epoch 91/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4516 - accuracy: 0.8431 - val_loss: 0.8877 - val_accuracy: 0.7195
#
# Epoch 00091: val_accuracy did not improve from 0.72050
# Epoch 92/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.4492 - accuracy: 0.8437 - val_loss: 0.8912 - val_accuracy: 0.7200
#
# Epoch 00092: val_accuracy did not improve from 0.72050
# Epoch 93/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4470 - accuracy: 0.8442 - val_loss: 0.8866 - val_accuracy: 0.7150
#
# Epoch 00093: val_accuracy did not improve from 0.72050
# Epoch 94/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4458 - accuracy: 0.8444 - val_loss: 0.9505 - val_accuracy: 0.7050
#
# Epoch 00094: val_accuracy did not improve from 0.72050
# Epoch 95/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4450 - accuracy: 0.8445 - val_loss: 0.9136 - val_accuracy: 0.7135
#
# Epoch 00095: val_accuracy did not improve from 0.72050
# Epoch 96/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4444 - accuracy: 0.8461 - val_loss: 0.9207 - val_accuracy: 0.7155
#
# Epoch 00096: val_accuracy did not improve from 0.72050
# Epoch 97/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4440 - accuracy: 0.8464 - val_loss: 0.8991 - val_accuracy: 0.7140
#
# Epoch 00097: val_accuracy did not improve from 0.72050
# Epoch 98/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4401 - accuracy: 0.8469 - val_loss: 0.9001 - val_accuracy: 0.7090
#
# Epoch 00098: val_accuracy did not improve from 0.72050
# Epoch 99/100
# 1172/1172 [==============================] - 15s 13ms/step - loss: 0.4389 - accuracy: 0.8463 - val_loss: 0.8921 - val_accuracy: 0.7155
#
# Epoch 00099: val_accuracy did not improve from 0.72050
# Epoch 100/100
# 1172/1172 [==============================] - 16s 13ms/step - loss: 0.4389 - accuracy: 0.8468 - val_loss: 0.8946 - val_accuracy: 0.7065
#
# Epoch 00100: val_accuracy did not improve from 0.72050

# %%
'''
# 순차 모델 생성 (가장 기본구조)
model = keras.Sequential()

# Flatten layer: 32 x 32 x 3 image를 3072개의 1D vector input으로 변환
model.add(keras.layers.Flatten(input_shape=input_shape))

# 1st hidden layer: fully-connected layer
# (# of inputs = 3072, # of outputs = 512, actication fuction = relu)
model.add(keras.layers.Dense(512, activation=tf.nn.relu))

# 2nd hidden layer: fully-connected layer 
# (# of inputs = 512, # of outputs = 256, actication fuction = relu)
model.add(keras.layers.Dense(256, activation=tf.nn.relu))

# 3rd hidden layer: fully-connected layer 
# (# of inputs = 256, # of outputs = 64, actication fuction = relu)
model.add(keras.layers.Dense(64, activation=tf.nn.relu))

# Output layer: fully-connected layer 
# (# of inputs = 64, # of outputs = 10, actication fuction = softmax)
model.add(keras.layers.Dense(num_classes, activation=tf.nn.softmax))

# 모델 컴파일
# optimizer: 모델을 업데이트 하는 방식
# loss: 모델의 정확도를 판단하는 방식
# metrics: 트레이닝 및 테스팅 성능 모니터링을 위한 평가지표
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])


# 체크포인트 생성
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath='/content/checkpoint_entire_best.h5', monitor='val_accuracy', verbose=1, save_weight_only=False, save_best_only=True, mode='auto')

# 모델 트레이닝
# batch_size: 전체 데이터셋 중 몇개씩 학습시킬 것인지
# epoch: 학습에 전체 데이터셋이 총 몇번 이용될 것인지
# shuffle: 학습전에 트레이닝 데이터셋을 랜덤하게 섞을 것인지
# validation_data: 중간 성능 검증에 사용할 data set (x_test1_after, x_test2_after, 혹은 둘을 merge해서 사용)
model.fit(x_train_after, y_train, batch_size = 128, epochs = 5, shuffle=True, callbacks=[cp_callback], validation_data=(x_test2_after, y_test2))
'''

# %% [markdown]
# # **4. 모델 저장**

# %%
save_path = '/content/'
team_name = 'team10'

# 트레이닝된 전체 모델을 저장합니다.
model.save(save_path +  'model_entire_'+ team_name + '.h5')

# %% [markdown]
# # **5. 모델 로드 및 평가**

# %%
save_path = '/content/'
team_name = 'team10'

model = keras.models.load_model(save_path + 'model_entire_' + team_name + '.h5')

model.evaluate(x_test1_after, y_test1)
model.evaluate(x_test2_after, y_test2)
# Out:
# 313/313 [==============================] - 2s 4ms/step - loss: 0.4943 - accuracy: 0.8385
# 63/63 [==============================] - 0s 3ms/step - loss: 0.8946 - accuracy: 0.7065
# [0.894612193107605, 0.7064999938011169]
